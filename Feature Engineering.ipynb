# %%
#Importing library

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Read the CSV file

fintech_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bitcoin CSV.csv')
fintech_df
# Out:
#              unix              date   symbol      open      high       low  \
# 0      1526364000    5/15/2018 6:00  BTC/USD   8733.86   8796.68   8707.28
# 1      1526367600    5/15/2018 7:00  BTC/USD   8740.99   8766.00   8721.11
# 2      1526371200    5/15/2018 8:00  BTC/USD   8739.00   8750.27   8660.53
# 3      1526374800    5/15/2018 9:00  BTC/USD   8728.49   8754.40   8701.35
# 4      1526378400   5/15/2018 10:00  BTC/USD   8708.32   8865.00   8695.11
# ...           ...               ...      ...       ...       ...       ...
# 39830  1669752000  11/29/2022 20:00  BTC/USD  16423.00  16489.00  16421.00
# 39831  1669755600  11/29/2022 21:00  BTC/USD  16487.00  16489.00  16453.00
# 39832  1669759200  11/29/2022 22:00  BTC/USD  16458.00  16487.00  16457.00
# 39833  1669762800  11/29/2022 23:00  BTC/USD  16487.00  16505.00  16434.00
# 39834  1669766400   11/30/2022 0:00  BTC/USD  16437.00  16453.00  16430.00
#
# ...

# %%
#Columns of the dataset :

    unix - A timestamp for the minute covered by the row.
    Count - The number of trades that took place this minute.
    Open - The USD price at the beginning of the minute.
    High - The highest USD price during the minute.
    Low - The lowest USD price during the minute.
    Close - The USD price at the end of the minute.
    Volume - The number of cryptoasset units traded during the minute.
    VWAP - The volume weighted average price for the minute.
    Target - 15 minute residualized returns.
    volatility-RV - realized volatility (RV) to better gauge the relative attractiveness of a given trading opportunity.
    volatility_parkinson - Parkinson volatility is a volatility measure that uses the stock’s high and low price of the day.
# Out:
#   File "<ipython-input-1-65a92b737731>", line 3
#     unix - A timestamp for the minute covered by the row.
#     ^
# IndentationError: unexpected indent

# %%
fintech_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39835 entries, 0 to 39834
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unix                  39835 non-null  int64
#  1   date                  39835 non-null  object
#  2   symbol                39835 non-null  object
#  3   open                  39835 non-null  float64
#  4   high                  39835 non-null  float64
#  5   low                   39835 non-null  float64
#  6   close                 39835 non-null  float64
#  7   Volume BTC            39835 non-null  float64
#  8   Volume USD            39835 non-null  float64
#  9   Return                2924 non-null   float64
#  10  volatility-RV         2924 non-null   float64
#  11  volatility_parkinson  2925 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 3.6+ MB

# %%
fintech_df.describe()
# Out:
#                unix          open          high           low         close  \
# count  3.983500e+04  39835.000000  39835.000000  39835.000000  39835.000000
# mean   1.598065e+09  21224.745751  21339.098316  21101.724779  21225.069932
# std    4.139827e+07  17524.628419  17624.834674  17416.123624  17524.703310
# min    1.526364e+09   3139.760000   3158.340000   3122.280000   3139.760000
# 25%    1.562215e+09   7466.075000   7499.500000   7433.690000   7466.075000
# 50%    1.598065e+09  11331.890000  11374.620000  11266.180000  11333.050000
# 75%    1.633916e+09  36265.955000  36537.980000  35947.115000  36267.755000
# max    1.669766e+09  68635.050000  69000.000000  68447.000000  68627.010000
#
#          Volume BTC    Volume USD       Return  volatility-RV  \
# count  3.983500e+04  3.983500e+04  2924.000000    2924.000000
# mean   1.346223e+06  2.889299e+06    -0.010054       0.425712
# std    2.897219e+06  6.855270e+06     0.652500       1.999327
# ...

# %%
#New Feature - Date Month Year

fintech_df['Day_since_started'] = sorted(fintech_df.index.to_list() , reverse = True)

# %%
fintech_df['date'] = pd.to_datetime(fintech_df['date']) #.astype('datetimetype')

# %%
fintech_df['day'] = fintech_df['date'].dt.day
fintech_df['month'] = fintech_df['date'].dt.month
fintech_df['year'] = fintech_df['date'].dt.year
fintech_df['week'] = fintech_df['date'].dt.week

fintech_df['weekday'] = fintech_df['date'].dt.weekday

fintech_df['weekend'] = fintech_df['date'].dt.weekday == (6 or 7 )
fintech_df
# Out:
#              unix                date   symbol      open      high       low  \
# 0      1526364000 2018-05-15 06:00:00  BTC/USD   8733.86   8796.68   8707.28
# 1      1526367600 2018-05-15 07:00:00  BTC/USD   8740.99   8766.00   8721.11
# 2      1526371200 2018-05-15 08:00:00  BTC/USD   8739.00   8750.27   8660.53
# 3      1526374800 2018-05-15 09:00:00  BTC/USD   8728.49   8754.40   8701.35
# 4      1526378400 2018-05-15 10:00:00  BTC/USD   8708.32   8865.00   8695.11
# ...           ...                 ...      ...       ...       ...       ...
# 39830  1669752000 2022-11-29 20:00:00  BTC/USD  16423.00  16489.00  16421.00
# 39831  1669755600 2022-11-29 21:00:00  BTC/USD  16487.00  16489.00  16453.00
# 39832  1669759200 2022-11-29 22:00:00  BTC/USD  16458.00  16487.00  16457.00
# 39833  1669762800 2022-11-29 23:00:00  BTC/USD  16487.00  16505.00  16434.00
# 39834  1669766400 2022-11-30 00:00:00  BTC/USD  16437.00  16453.00  16430.00
#
# ...
